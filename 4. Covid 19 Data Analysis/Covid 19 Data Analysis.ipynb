# %%
import pandas as pd

# %%
df = pd.read_csv('Covid19 Dataset.csv')
df
# Out:
#           Date     State          Region  Confirmed  Deaths  Recovered
# 0    4/29/2020       NaN     Afghanistan       1939      60        252
# 1    4/29/2020       NaN         Albania        766      30        455
# 2    4/29/2020       NaN         Algeria       3848     444       1702
# 3    4/29/2020       NaN         Andorra        743      42        423
# 4    4/29/2020       NaN          Angola         27       2          7
# ..         ...       ...             ...        ...     ...        ...
# 316  4/29/2020   Wyoming              US        545       7          0
# 317  4/29/2020  Xinjiang  Mainland China         76       3         73
# 318  4/29/2020     Yukon          Canada         11       0          0
# 319  4/29/2020    Yunnan  Mainland China        185       2        181
# 320  4/29/2020  Zhejiang  Mainland China       1268       1       1263
#
# [321 rows x 6 columns]

# %%
df.count()
# Out:
# Date         321
# State        140
# Region       321
# Confirmed    321
# Deaths       321
# Recovered    321
# dtype: int64

# %%
df.isnull().sum()
# Out:
# Date           0
# State        181
# Region         0
# Confirmed      0
# Deaths         0
# Recovered      0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 321 entries, 0 to 320
# Data columns (total 6 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Date       321 non-null    object
#  1   State      140 non-null    object
#  2   Region     321 non-null    object
#  3   Confirmed  321 non-null    int64
#  4   Deaths     321 non-null    int64
#  5   Recovered  321 non-null    int64
# dtypes: int64(3), object(3)
# memory usage: 15.2+ KB

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
plt.figure(figsize=(4,3))
sns.heatmap(df.isnull())
plt.show()

# %% [markdown]
# #### Q1. Show the number of confirmed, Deaths and recovered cases in each region.

# %%
df.groupby('Region')['Confirmed'].sum().sort_values(ascending = False).head()
# Out:
# Region
# US        1039909
# Spain      236899
# Italy      203591
# France     166543
# UK         166441
# Name: Confirmed, dtype: int64

# %%
df.groupby('Region')['Deaths'].sum().sort_values(ascending = False).head(10)
# Out:
# Region
# US             60967
# Italy          27682
# UK             26166
# Spain          24275
# France         24121
# Belgium         7501
# Germany         6467
# Iran            5957
# Brazil          5513
# Netherlands     4727
# Name: Deaths, dtype: int64

# %%
df.groupby('Region')['Recovered'].sum().sort_values(ascending = False).head(10)
# Out:
# Region
# Spain             132929
# US                120720
# Germany           120400
# Mainland China     77610
# Iran               73791
# Italy              71252
# France             49118
# Turkey             44040
# Brazil             34132
# Switzerland        22600
# Name: Recovered, dtype: int64

# %% [markdown]
# ### OR

# %%
df.groupby('Region')['Confirmed','Deaths','Recovered'].sum().head(10)
# Out:
# C:\Users\abhis\AppData\Local\Temp\ipykernel_30352\1547705607.py:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   df.groupby('Region')['Confirmed','Deaths','Recovered'].sum().head(10)
#                      Confirmed  Deaths  Recovered
# Region
# Afghanistan               1939      60        252
# Albania                    766      30        455
# Algeria                   3848     444       1702
# Andorra                    743      42        423
# Angola                      27       2          7
# Antigua and Barbuda         24       3         11
# Argentina                 4285     214       1192
# Armenia                   1932      30        900
# Australia                 6752      91       5715
# Austria                  15402     580      12779

# %% [markdown]
# #### Q2. Remove all the records where confirmed cases is less than 10.

# %%
df = df[~(df.Confirmed < 10)]
df
# Out:
#           Date     State          Region  Confirmed  Deaths  Recovered
# 0    4/29/2020       NaN     Afghanistan       1939      60        252
# 1    4/29/2020       NaN         Albania        766      30        455
# 2    4/29/2020       NaN         Algeria       3848     444       1702
# 3    4/29/2020       NaN         Andorra        743      42        423
# 4    4/29/2020       NaN          Angola         27       2          7
# ..         ...       ...             ...        ...     ...        ...
# 316  4/29/2020   Wyoming              US        545       7          0
# 317  4/29/2020  Xinjiang  Mainland China         76       3         73
# 318  4/29/2020     Yukon          Canada         11       0          0
# 319  4/29/2020    Yunnan  Mainland China        185       2        181
# 320  4/29/2020  Zhejiang  Mainland China       1268       1       1263
#
# [304 rows x 6 columns]

# %% [markdown]
# #### Q3. In which Region, maximum number of confirmed cases were recorded?

# %%
df.groupby('Region')['Confirmed'].sum().sort_values(ascending = False).head(1)
# Out:
# Region
# US    1039909
# Name: Confirmed, dtype: int64

# %% [markdown]
# #### Q4. In which region, minimum number of deaths cases were recorded?

# %%
df.groupby('Region')['Deaths'].sum().sort_values(ascending = True).head(30)
# Out:
# Region
# Cambodia                            0
# Seychelles                          0
# Saint Lucia                         0
# Central African Republic            0
# Saint Kitts and Nevis               0
# South Sudan                         0
# Rwanda                              0
# Grenada                             0
# Macau                               0
# Madagascar                          0
# Nepal                               0
# Namibia                             0
# Saint Vincent and the Grenadines    0
# Mozambique                          0
# Holy See                            0
# Timor-Leste                         0
# Mongolia                            0
# Uganda                              0
# Laos                                0
# Eritrea                             0
# Vietnam                             0
# Fiji                                0
# Dominica                            0
# Gambia                              1
# ...

# %% [markdown]
# #### Q5. How many confirmed, deaths & recovered cases were reported from India till 29 april 2020?

# %%
df[df.Region == 'India']
# Out:
#          Date State Region  Confirmed  Deaths  Recovered
# 74  4/29/2020   NaN  India      33062    1079       8437

# %% [markdown]
# #### Q6. A) Sort the entire data wrt No. of confirmed cases in asc order.

# %%
df.sort_values(by= ['Confirmed'], ascending = True)
# Out:
#           Date      State    Region  Confirmed  Deaths  Recovered
# 156  4/29/2020        NaN  Suriname         10       1          8
# 70   4/29/2020        NaN  Holy See         10       0          2
# 59   4/29/2020        NaN    Gambia         10       1          8
# 318  4/29/2020      Yukon    Canada         11       0          0
# 217  4/29/2020  Greenland   Denmark         11       0         11
# ..         ...        ...       ...        ...     ...        ...
# 57   4/29/2020        NaN    France     165093   24087      48228
# 168  4/29/2020        NaN        UK     165221   26097          0
# 80   4/29/2020        NaN     Italy     203591   27682      71252
# 153  4/29/2020        NaN     Spain     236899   24275     132929
# 265  4/29/2020   New York        US     299691   23477          0
#
# [304 rows x 6 columns]

# %% [markdown]
# #### Q6. B) Sort the entire data wrt No. of recovered cases in desc order.

# %%
df.sort_values(by= ['Recovered'], ascending = False)
# Out:
#           Date     State          Region  Confirmed  Deaths  Recovered
# 153  4/29/2020       NaN           Spain     236899   24275     132929
# 61   4/29/2020       NaN         Germany     161539    6467     120400
# 76   4/29/2020       NaN            Iran      93657    5957      73791
# 80   4/29/2020       NaN           Italy     203591   27682      71252
# 229  4/29/2020     Hubei  Mainland China      68128    4512      63616
# ..         ...       ...             ...        ...     ...        ...
# 258  4/29/2020    Nevada              US       4934     230          0
# 257  4/29/2020  Nebraska              US       3851      56          0
# 255  4/29/2020   Montana              US        451      16          0
# 254  4/29/2020  Missouri              US       7660     338          0
# 274  4/29/2020      Ohio              US      17303     937          0
#
# [304 rows x 6 columns]
